# %% [markdown]
# https://huggingface.co/ZB-Tech/Text-to-Image?text=Draw+a+picture+of+two+female+boxers+fighting+each+other.

# %%
import requests
from utils import *

device = "cuda" if torch.cuda.is_available() else "cpu"

API_URL = "https://api-inference.huggingface.co/models/ZB-Tech/Text-to-Image"
headers = {"Authorization": "Bearer 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"}

# %%
def query(payload):
    response = requests.post(API_URL, headers=headers, json=payload)
    return response.content
image_bytes = query({
    "inputs": "They continued walking, the sound of crunching leaves underfoot the only noise accompanying them",
})
# You can access the image with PIL.Image for example
import io
from PIL import Image
image = Image.open(io.BytesIO(image_bytes))
display(image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x1024>
